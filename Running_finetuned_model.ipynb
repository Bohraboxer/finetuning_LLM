# %%
# !pip install accelerate                     # For speeding up training on multi-GPU setups
# !pip install --upgrade transformers         # For working with Hugging Face transformer models
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 76.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 31.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.3
#     Uninstalling transformers-4.46.3:
#       Successfully uninstalled transformers-4.46.3
# ...

# %%
from huggingface_hub import notebook_login
from google.colab import userdata
import torch

# Retrieve Hugging Face token securely (saved via Colab userdata)
hf_token = userdata.get('hftoken')
notebook_login()

# %%
# pip install accelerate
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b", device_map="auto")

input_text = "Write me a poem about Machine Learning."
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# ...
# model-00001-of-00002.safetensors:  96%|#########6| 4.76G/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# <bos>Write me a poem about Machine Learning.
#
# I’m not sure what you mean by “write me a poem about Machine Learning.”

# %%
import datetime

a = datetime.datetime.now()
input_text = "Were Mughals brutal?"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids, max_length=100)
b = datetime.datetime.now()

print(tokenizer.decode(outputs[0]))
print("Time taken to execute the base model", b-a)
# Out:
# <bos>Were Mughals brutal?
#
# The Mughals were a Muslim dynasty that ruled over the Indian subcontinent from the 16th to the 18th century. They were known for their military conquests and their cultural influence, but they were also known for their brutality and cruelty.
#
# The Mughals were known for their brutal treatment of their enemies, both on the battlefield and in their own ranks. They were also known for their use of torture and execution as a form of punishment.
#
#
# Time taken to execute the base model 0:00:04.202633

# %%
a = datetime.datetime.now()
input_text = "What was the first invention of human that was a game changer?"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids)
b = datetime.datetime.now()

print(tokenizer.decode(outputs[0]))
print("Time taken to execute the base model", b-a)
# Out:
# <bos>What was the first invention of human that was a game changer?
#
# The first invention of human that was a game changer was the wheel. The wheel was invented by
# Time taken to execute the base model 0:00:00.917975

# %%
a = datetime.datetime.now()
input_text = "What is bigger? A brick or a palace?"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids, max_length=100)
b = datetime.datetime.now()

print(tokenizer.decode(outputs[0]))
print("Time taken to execute the base model", b-a)
# Out:
# <bos>What is bigger? A brick or a palace?
#
# A brick is a brick, but a palace is a palace.
#
# A brick is a brick, but a palace is a palace.
#
# A brick is a brick, but a palace is a palace.
#
# A brick is a brick, but a palace is a palace.
#
# A brick is a brick, but a palace is a palace.
#
# A brick is a brick, but a palace is a palace.
#
# A brick is a
# Time taken to execute the base model 0:00:04.341002

# %%
a = datetime.datetime.now()

input_text = "How to grow mushroom at home?"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids, max_length=100)
b = datetime.datetime.now()

print(tokenizer.decode(outputs[0]))
print("Time taken to execute the base model", b-a)
# Out:
# <bos>How to grow mushroom at home?
#
# Mushroom is a type of fungus that grows on the surface of the soil. It is a type of fungus that grows on the surface of the soil. It is a type of fungus that grows on the surface of the soil. It is a type of fungus that grows on the surface of the soil. It is a type of fungus that grows on the surface of the soil. It is a type of fungus that grows on the surface of the soil. It
# Time taken to execute the base model 0:00:04.030936

# %%
import torch

tokenizer = AutoTokenizer.from_pretrained("RohitBohra/finetuned_combined_gemma-2b")
model = AutoModelForCausalLM.from_pretrained(
    "RohitBohra/finetuned_combined_gemma-2b",
    device_map="auto",
    torch_dtype=torch.float16  # Use torch_dtype for precision
)

input_text = "Write me a poem about Machine Learning."
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# tokenizer_config.json:   0%|          | 0.00/40.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/34.4M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/522 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/703 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# <bos>Write me a poem about Machine Learning.
#
# Response:
# I'm a machine learning algorithm,
# I'm a machine learning algorithm

# %%
import datetime

a = datetime.datetime.now()
input_text = "Were Mughals brutal?"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids, max_length=100)
b = datetime.datetime.now()

print(tokenizer.decode(outputs[0]))
print("Time taken to execute the finetuned model", b-a)
# Out:
# <bos>Were Mughals brutal?
#
# Response:
# The Mughals were a Muslim dynasty that ruled over the Indian subcontinent from 1526 to 1858. They were known for their military conquests and their cultural contributions to the region. However, there is some debate about whether or not they were brutal. Some historians argue that they were not as brutal as they are often portrayed, while others argue that they were.<eos>
# Time taken to execute the finetuned model 0:00:02.508991

# %%
a = datetime.datetime.now()
input_text = "What was the first invention of human that was a game changer?"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids)
b = datetime.datetime.now()

print(tokenizer.decode(outputs[0]))
print("Time taken to execute the finetuned model", b-a)
# Out:
# <bos>What was the first invention of human that was a game changer?
#
# Response:
# The first invention that was a game changer was the wheel.  The wheel was
# Time taken to execute the finetuned model 0:00:00.899586

# %%
a = datetime.datetime.now()
input_text = "What is bigger? A brick or a palace?"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids, max_length=100)
b = datetime.datetime.now()

print(tokenizer.decode(outputs[0]))
print("Time taken to execute the finetuned model", b-a)
# Out:
# <bos>What is bigger? A brick or a palace?
#
# Response:
# A palace is bigger than a brick. A palace is a large building with many rooms and many people living in it. A brick is a small building with only a few rooms and a few people living in it.<eos>
# Time taken to execute the finetuned model 0:00:02.113679

# %%
a = datetime.datetime.now()

input_text = "How to grow mushroom at home?"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids, max_length=100)
b = datetime.datetime.now()

print(tokenizer.decode(outputs[0]))
print("Time taken to execute the finetuned model", b-a)
# Out:
# <bos>How to grow mushroom at home?
#
# Response:
# Mushroom can be grown at home by using a substrate. The substrate can be made of sawdust, rice, wheat, etc. The substrate is then inoculated with mushroom spores. The mushroom spores are then incubated in a humid environment for a few days. The mushroom will then start to grow and can be harvested after a few weeks.<eos>
# Time taken to execute the finetuned model 0:00:02.497083
